# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal

# %%
for i in range(1,10):
    mu0 = np.array([i, -i])[np.newaxis, :]
    mu1 = np.array([2*i, -1*2*i])[np.newaxis, :]
    sigma = np.array([[1, 0], [0, 1]])

    N = 20
    #mu0 = np.random.randn(2)
    #mu1 = np.random.randn(2)
    # sigma = np.random.randn(2,2)
    # sigma = np.dot(sigma, sigma.T)
    X0 = np.random.multivariate_normal(mu0.ravel(), sigma, N)
    X1 = np.random.multivariate_normal(mu1.ravel(), sigma, N)

    print(mu0)
    print(mu1)
    print(sigma)

    plt.scatter(X0[:,0], X0[:,1], color='red')
    plt.scatter(X1[:,0], X1[:,1], color='blue')
    plt.show()
# Out:
# [[ 1 -1]]
# [[ 2 -2]]
# [[1 0]
#  [0 1]]
# [[ 2 -2]]
# [[ 4 -4]]
# [[1 0]
#  [0 1]]
# [[ 3 -3]]
# [[ 6 -6]]
# [[1 0]
#  [0 1]]
# [[ 4 -4]]
# [[ 8 -8]]
# [[1 0]
#  [0 1]]
# [[ 5 -5]]
# [[ 10 -10]]
# [[1 0]
#  [0 1]]
# [[ 6 -6]]
# [[ 12 -12]]
# [[1 0]
#  [0 1]]
# [[ 7 -7]]
# [[ 14 -14]]
# [[1 0]
#  [0 1]]
# [[ 8 -8]]
# [[ 16 -16]]
# [[1 0]
#  [0 1]]
# [[ 9 -9]]
# [[ 18 -18]]
# [[1 0]
#  [0 1]]
